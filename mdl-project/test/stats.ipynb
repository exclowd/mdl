# %%
test = open('test.txt')
train = open('train.txt')

from save import *

test_arr = session.query(Data.vector_0, Data.mse_test).filter(Data.mse_train < 7e10, Data.mse_test < 7e10)

# while line := test.readline():
#     test_arr.append(float(line.strip()))
#
# while line := train.readline():
#     train_arr.append(float(line.strip()))

import numpy as np
import matplotlib.pyplot as plt

a = np.zeros(test_arr.count())
b = np.zeros(test_arr.count())
i = 0
for vec in test_arr:
    a[i], b[i] = vec
    i += 1

# a = np.array(test_arr)
# b = np.array(train_arr)

plt.scatter(a, b)

# %%
test_arr = session.query(Data.vector_1, Data.mse_test).filter(Data.mse_train < 7e10, Data.mse_test < 7e10)

# while line := test.readline():
#     test_arr.append(float(line.strip()))
#
# while line := train.readline():
#     train_arr.append(float(line.strip()))

import numpy as np
import matplotlib.pyplot as plt

a = np.zeros(test_arr.count())
b = np.zeros(test_arr.count())
i = 0
for vec in test_arr:
    a[i], b[i] = vec
    i += 1

# a = np.array(test_arr)
# b = np.array(train_arr)

plt.scatter(a, b)

# %%
test_arr = session.query(Data.vector_2, Data.mse_test).filter(Data.mse_train < 7e10, Data.mse_test < 7e10)

# while line := test.readline():
#     test_arr.append(float(line.strip()))
#
# while line := train.readline():
#     train_arr.append(float(line.strip()))

import numpy as np
import matplotlib.pyplot as plt

a = np.zeros(test_arr.count())
b = np.zeros(test_arr.count())
i = 0
for vec in test_arr:
    a[i], b[i] = vec
    i += 1

# a = np.array(test_arr)
# b = np.array(train_arr)

plt.scatter(a, b)

# %%
test_arr = session.query(Data.vector_3, Data.mse_test).filter(Data.mse_train < 7e10, Data.mse_test < 7e10)

# while line := test.readline():
#     test_arr.append(float(line.strip()))
#
# while line := train.readline():
#     train_arr.append(float(line.strip()))

import numpy as np
import matplotlib.pyplot as plt

a = np.zeros(test_arr.count())
b = np.zeros(test_arr.count())
i = 0
for vec in test_arr:
    a[i], b[i] = vec
    i += 1

# a = np.array(test_arr)
# b = np.array(train_arr)

plt.scatter(a, b)
